# %% [markdown]
# Task1:

# %% [markdown]
# 1. Write your city then print it

# %%
city = "chennai"
print(city)
# Out:
# chennai

# %% [markdown]
# 2. Create a input for age

# %%
age = input()
print("my age is" ,age)
# Out:
#  19
# my age is 19

# %% [markdown]
# Task2:

# %% [markdown]
# 1. Write a programme to check if a person is eligible to vote (age>=18)

# %%
age = int(input())
if  (age>=18):
   print("Eligible for vote")
else:
 print("Not eligible for vote")
# Out:
#  19
# Eligible for vote

# %% [markdown]
# 2. Write a programme to check if a student has passed (marks>=40)

# %%
mark = int(input("mark:"))
if (mark>=40):
    print("Student has passed")
else:
 print("Student has fail")
# Out:
# mark: 45
# Student has passed

# %% [markdown]
# 3. Create a variable cell_count to store the number of cells in a sample (e.g., 2,000). Print it.

# %%
cell_count = 2000
print(cell_count)
# Out:
# 2000

# %% [markdown]
# 4. Store the number of base pairs in a gene in a variable. Print: The gene has X base pairs.

# %%
gene = 15000
print(gene)
# Out:
# 15000

# %% [markdown]
# 5. Store beats_per_minute = 72. Calculate total beats in one hour using a variable.

# %%
beats_per_minute = 72
total_beats = beats_per_minute*60
print("total_beats",total_beats)
# Out:
# total_beats 4320

# %% [markdown]
# 6. Store solute = 5 grams and volume = 250 mL. Calculate concentration

# %%
solute = 5
volume = 250
concentration = solute/volume
print("concentration:" ,concentration)
# Out:
# concentration: 0.02

# %% [markdown]
# 7. Create a variable molar_mass_water = 18. Print it.

# %%
molar_mass_water = 18
print("molar_mass_water:" ,molar_mass_water)
# Out:
# molar_mass_water: 18

# %% [markdown]
# Task3:

# %% [markdown]
# Write a program that calculates BMI and classifies it as Underweight, Normal, Overweight, or Obese using if-elif-else

# %%
a= float(input("enter your height"))
b = int(input("enter your weight"))
bmi = b/a*a
if(bmi<18.5):
   print("under weight")
elif(bmi>=18.5 , bmi <25):
     print("normal weight")
else:
  print("over weight")
# Out:
# enter your height 4.5
# enter your weight 50
# normal weight

# %% [markdown]
# 2. Input fasting blood sugar level and find whether its normal, pre-diabetes or diabetes

# %%
blood_sugar_level = int(input("blood_suger_level:"))
if(blood_sugar_level>50):
    print("normal")
elif(blood_sugar_level>=50 , blood_sugar_level>80):
    print("chances of diabetes")
else:
 print("something problem")
# Out:
# blood_suger_level: 50
# chances of diabetes

# %% [markdown]
# 3. Check loan eligibility based on Input salary and credit score.

# %%
salary = int(input("salary:"))
credit_score = float(input("credit_score:"))
if(salary>30000 , credit_score>30):
    print("eligible for loan")
else:
 print("not eligible for loan")
# Out:
# salary: 45000
# credit_score: 45.6
# eligible for loan

# %% [markdown]
# 4. wite a program that calculates guessing the number.

# %%
guess_the_number = int(input())
if(guess_the_number==108):
    print("correct")
elif(guess_the_number>109):
    print("the number is greater than", guess_the_number)
else:
 print("Invalid number")
# Out:
#  -12
# Invalid number
